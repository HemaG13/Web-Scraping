# %%
import urllib
from bs4 import BeautifulSoup
import re
import requests
import csv
import pandas as pd
from matplotlib import pyplot as plt
no = [6175,6881,4613,5164,3192,
      4195,3194,2008,6822,6273,
      6122,6809,1002,1101,2130,
      6323,2138,4118,5331,4302,
      3219,6276,6139,6787,6620,
      1128,3184,2132,2020,6004,
      6028,6275,5104,6152,4304,
      6179,5108,5160,5162,4134,
      4178,4186,5322,4192,3181,
      3176,4167,1148,3188,3423]


urll = []
for j in no:
    urll.append('http://dtemaharashtra.gov.in/frmInstituteSummary.aspx?InstituteCode='+str(j))
clgnam = []
location = []
contact = []
website = []
email = []
for i in urll:
    html = urllib.request.urlopen(i).read()
    soup = BeautifulSoup(html)
    try:
            clg = soup.find("span",{'id':"ctl00_ContentPlaceHolder1_lblInstituteNameEnglish"}).text
            if len(clg) >= 1:
                clgnam.append(clg)
            else:
                clgnam.append("NA")

            loc = soup.find('span',{'id':'ctl00_ContentPlaceHolder1_lblRegion'}).text
            if len(loc) >= 1:
                location.append(loc)
            else:
                location.append("NA")

            cont = soup.find('span',{'id':'ctl00_ContentPlaceHolder1_lblOfficePhoneNo'}).text
            if len(cont) >= 1:
                contact.append(cont)
            else:
                contact.append("NA")

            web = soup.find('span',{'id':'ctl00_ContentPlaceHolder1_lblWebAddress'}).text
            if len(web) >= 1:
                website.append(web)
            else:
                website.append("NA")
                print("appended")

            mail = soup.find('span',{'id':'ctl00_ContentPlaceHolder1_lblEMailAddress'}).text
            if len(mail) >= 1:
                email.append(mail)
            else:
                email.append("NA")        
    except Exception as e:
        print(e)

# %%
tpn = []
tpon = []

urlp = ['http://www.pccoepune.com/iii-home.php',
        'https://www.aitpune.com/Placements.aspx',
        'http://scetngp.com/introduction-tpo/',
        'http://www.coeshahada.ac.in/contact-tpo.php',
        'http://www.sigce.edu.in/tpo.asp#undefined3',
        'http://www.agpce.com/Training_Placement.php',
        'https://www.vcet.edu.in/placements-2/',
        'http://tpo.geca.ac.in/Contact.aspx'
        ]
        #6175,6881,4613,5164,3192,4195,3194,2008

up = ['http://pccoer.com/tpo-desk.php']
      #6822

url = ['http://www.vit.edu/index.php/placements/placement-office',
       'https://pvpittssm.edu.in/placements/about',
       'http://www.shivgangavtc.org/placement/',
       'https://gcoea.ac.in/index.php/training-placement/training-and-placement-contact-us/',
       'https://www.ssgmce.ac.in/ssgmce/training-placement-cell/contact-info.php',
       'http://www.coea.ac.in/TPO.htm', 
       'http://www.msscetjalna.org/TPO.html',
       'http://www.rsce.ac.in/contactTNP.php',
       'http://www.bdce.edu.in/TnP/team_TnP',
       'https://www.sandipfoundation.org/placement/placement-cell.php',
       'http://www.mietbhandara.ac.in/DisplayDeptPage.aspx?page=ec&ItemID=36&nDeptID=10017'
       ]
        #6273,6122,6809,1002,1101,2130,6323,2138,4118,5331,4302

urlmb = ['http://armiet.in/placements/']
        #3219

urlp9 = ['https://www.cumminscollege.org/placements/overview/',
         'https://moderncoe.edu.in/placement_committee.php'
         ]
        #6276,6139,

urlp94 = ['http://mitcorer.edu.in/placement-details',
       'http://dypsoeambi.com/tpo_overview']
      #6787,6620

urlp99 =['https://prmceam.ac.in/team/',
         'http://www.fragnel.edu.in/index.php/students/placements/campus-placement-overview']
        #1128,,3184

urldp = ['https://www.jnec.org/placement.php']
      #2132
urlds = ['https://sggs.ac.in/training-and-placement/']
        #2020

urldl = ['http://www.gcoeara.ac.in/training-placement.php',
         'http://www.unishivaji.ac.in/placement/Placement-Officers-Desk'
         ]
         #6004,6028

urldl95 = ['http://engg.svpm.org.in/training-cell']
         #6275

urldl94  = ['http://www.sscoetjalgaon.ac.in/Placement/Default.asp' ]
        #5104

urlml = ['http://www.zibacar.in/t-p-o/',
         'http://www.cumminscollege.edu.in/contact.php']
          #6152,4304
#6152,4304,5104,6275,6004,6028,2020,2132
urlm = ['http://indiraicem.ac.in/index.php?/PlacementTeam',
        'https://kbtcoe.org/t-p-committee/',
        'http://www.sanjivanicoe.org.in/index.php/placements/placement-process-contacts',
        'http://www.avcoe.org/t&p.php',
        'https://gniet.ac.in/placement-cell/',
        'https://rgcer.edu.in/rgcer/t-p-team',
        'https://www.dmietr.edu.in/dmietr/T-and-P-team',
        'http://www.jiemsakk.com/placement.php',
        'http://www.nietm.in/role-training-placement.html',
        'https://kjsce.somaiya.edu/en/placement/commitees',
        'http://www.tcetmumbai.in/TNPContact.html'
        ]
         #6179,5108,5160,5162,4134,4178,4186,5322,4192,3181,3176
urlm98 = ['https://www.ycce.edu/t&p-team.php',
          'http://prppier.ac.in/contact.php',
          'http://www.pvppcoe.ac.in/_/placement']
          #4167,1148,3188
urlmll = ['https://www.slrtce.in/placement/']
#3423

try:
    for k in urlp:
        html = urllib.request.urlopen(k).read()
        soup = BeautifulSoup(html)
        for i in soup.strings:
            tpm = re.findall('Prof\W+\w+\W+\w+',i)
            if len(tpm) >= 1:
                tpon.append(tpm)
                break
        for i in soup.strings:
            noo = re.findall('[1-9]\d{9}',i)
            if len(noo) >= 1:
                tpn.append(noo)
                break
    for k in up:
        html = urllib.request.urlopen(k).read()
        soup = BeautifulSoup(html)
        for i in soup.strings:
            tpm = re.findall('Prof\W+S\w+\W+\w+\W+\w+',i)
            if len(tpm) >= 1:
                tpon.append(tpm)
                break
        for i in soup.strings:
            noo = re.findall('\d{10}',i)
            if len(noo) >= 1:
                tpn.append(noo)
                break

    for k in url:
        html = urllib.request.urlopen(k).read()
        soup = BeautifulSoup(html)
        for i in soup.strings:
            tpm = re.findall('Prof\W+\w+\W+\w+\W+\w+',i)
            if len(tpm) >= 1:
                tpon.append(tpm)
                break
        for i in soup.strings:
            tpm = re.findall('\d{10}',i)
            if len(tpm) >= 1:
                tpn.append(tpm)
                break

    for k in urlmb:
        html = urllib.request.urlopen(k).read()
        soup = BeautifulSoup(html)
        for i in soup.strings:
            tpm = re.findall('MR\W+\w+\W+\w+\W+\w+',i)
            if len(tpm) >= 1:
                tpon.append(tpm)
                break
        for i in soup.strings:
            no = re.findall('98\d{8}',i)
            if len(no) >= 1:
                tpn.append(no)
                break
        
    for k in urlp9:
        html = urllib.request.urlopen(k).read()
        soup = BeautifulSoup(html)
        for i in soup.strings:
            tpm = re.findall('Prof\W+\w+\W+\w+',i)
            if len(tpm) >= 1:
                tpon.append(tpm)
                break
        for i in soup.strings:
            noo = re.findall('9\d{9}',i)
            if len(noo) >= 1:
                tpn.append(noo)

    for k in urlp94:
        html = urllib.request.urlopen(k).read()
        soup = BeautifulSoup(html)
        for i in soup.strings:
            tpm = re.findall('Prof\W+\w+\W+\w+',i)
            if len(tpm) >= 1:
                tpon.append(tpm)
                break
        for i in soup.strings:
            noo = re.findall('94\d{8}',i)
            if len(noo) >= 1:
                tpn.append(noo)
                break
      
    for k in urlp99:
        html = urllib.request.urlopen(k).read()
        soup = BeautifulSoup(html)
        for i in soup.strings:
            tpm = re.findall('Prof\W+\w+\W+\w+',i)
            if len(tpm) >= 1:
                tpon.append(tpm)
                break
        for i in soup.strings:
            noo = re.findall('99\d{8}',i)
            if len(noo) >= 1:
                tpn.append(noo)
                break

    for k in urldp:
        html = urllib.request.urlopen(k).read()
        soup = BeautifulSoup(html)
        for i in soup.strings:
            tpm = re.findall('Dr. P\w+\W+\w+\W+\w+',i)
            if len(tpm) >= 1:
                tpon.append(tpm)
                break
        for i in soup.strings:
            noo = re.findall('\d{10}',i)
            if len(noo) >= 1:
                tpn.append(noo)
                break
    for k in urlds:
        html = urllib.request.urlopen(k).read()
        soup = BeautifulSoup(html)
        for i in soup.strings:
            tpm = re.findall('Mr\W+\w+\W+\w+',i)
            if len(tpm) >= 1:
                tpon.append(tpm)
                break
        for i in soup.strings:
            noo = re.findall('88\d{8}',i)
            if len(noo) >= 1:
                tpn.append(noo)
                break

    for k in urldl:
        html = urllib.request.urlopen(k).read()
        soup = BeautifulSoup(html)
        for i in soup.strings:
            tpm = re.findall('Dr\W+\w+\W+\w+\W+\w+',i)
            if len(tpm) >= 1:
                tpon.append(tpm)
                break
        for i in soup.strings:
            noo = re.findall('9\d{9}',i)
            if len(noo) >= 1:
                tpn.append(noo)
                break

    for k in urldl95:
        html = urllib.request.urlopen(k).read()
        soup = BeautifulSoup(html)
        for i in soup.strings:
            tpm = re.findall('Dr\W+\w+\W+\w+\W+\w+',i)
            if len(tpm) >= 1:
                tpon.append(tpm)
                break
        for i in soup.strings:
            noo = re.findall('95\d{8}',i)
            if len(noo) >= 1:
                tpn.append(noo)
                break

    for k in urldl94:
        html = urllib.request.urlopen(k).read()
        soup = BeautifulSoup(html)
        for i in soup.strings:
            tpm = re.findall('Dr\W+\w+\W+\w+\W+\w+',i)
            if len(tpm) >= 1:
                tpon.append(tpm)
                break
        for i in soup.strings:
            noo = re.findall('94\d{8}',i)
            if len(noo) >= 1:
                tpn.append(noo)
                break

    for k in urlml:
        html = urllib.request.urlopen(k).read()
        soup = BeautifulSoup(html)
        for i in soup.strings:
            tpm = re.findall('Mr\W+\w+\W+\w+\W+\w+',i)
            if len(tpm) >= 1:
                tpon.append(tpm)
                break
        for i in soup.strings:
            noo = re.findall('8\d{9}',i)
            if len(noo) >= 1:
                tpn.append(noo)
                break

    for k in urlm:
        html = urllib.request.urlopen(k).read()
        soup = BeautifulSoup(html)
        for i in soup.strings:
            tpm = re.findall('Mr\W+\w+\W+\w+',i)
            if len(tpm) >= 1:
                tpon.append(tpm)
                break
        for i in soup.strings:
            noo = re.findall('\d{10}',i)
            if len(noo) >= 1:
                tpn.append(noo)
                break

    for k in urlm98:
        html = urllib.request.urlopen(k).read()
        soup = BeautifulSoup(html)
        for i in soup.strings:
            tpm = re.findall('Mr\W+\w+\W+\w+',i)
            if len(tpm) >= 1:
                tpon.append(tpm)
                break
        for i in soup.strings:
            noo = re.findall('98\d{8}',i)
            if len(noo) >= 1:
                tpn.append(noo)
                break

    for k in urlmll:
        html = urllib.request.urlopen(k).read()
        soup = BeautifulSoup(html)
        for i in soup.strings:
            tpm = re.findall('Mr\W+\w+\W+\w+\W+\w+',i)
            if len(tpm) >= 1:
                tpon.append(tpm)
                break
        for i in soup.strings:
            noo = re.findall('\d{10}',i)
            if len(noo) >= 1:
                tpn.append(noo)
                break


except Exception as e:
        print(e)

# %%
try:
    data = pd.DataFrame({
    'College Name':clgnam,
    'College Location': location,
    'College Contact Number':contact,
    'College Website': website,
    'College Email': email,
    'TPO Name':tpon ,
    'TPO No': tpn
    })
    data.to_csv('scrap.csv',index=0)
    df = pd.read_csv('scrap.csv')
    files.download('scrap.csv')
    a=df['College Location'] 
    c=df['College Location'].value_counts()
    b = []
    city = []
        
    info = a.drop_duplicates()  
    for i in info:
        city.append(i)
            
    for i in c:
        b.append(i)
   
    fig = plt.figure()
    ax = fig.add_axes([0,0,1,1])
    ax.axis('equal')
    print(city)
    print(b)
    ax.pie(b, labels = city,autopct='%1.2f%%')
    
    plt.show()
except Exception as e:
        print("Error is",e)
# Out:
# ['Pune', 'Nagpur', 'Nashik', 'Mumbai', 'Aurangabad', 'Amravati']
# [16, 10, 8, 7, 5, 4]

# %%
df.head(50)
# Out:
#                                          College Name  ...                        TPO No
# 0   Pimpri Chinchwad Education Trust, Pimpri Chinc...  ...                ['9422792663']
# 1                  Army Institute of Technology, Pune  ...  ['7249250184', '7249250185']
# 2   Suryodaya College of Engineering & Technology,...  ...                ['7020736605']
# 3   P.S.G.V.P. Mandal's D.N. Patel College of Engi...  ...                ['9423194789']
# 4   Smt. Indira Gandhi College of Engineering, Nav...  ...                ['8080949300']
# 5   Vidharbha Bahu uddeshiya Shikshan Sanstha's Ab...  ...                ['8805000935']
# 6   Vidyavardhini's College of Engineering and Tec...  ...  ['7710070970', '9987173606']
# 7      Government College of Engineering,  Aurangabad  ...                ['8275034234']
# 8   Pimpri Chinchwad Education Trust's Pimpri Chin...  ...                ['8149951296']
# ...
